# %% [markdown]
# <a href="https://colab.research.google.com/github/can-yaman-88/Colab/blob/main/BasitHesapMakinesi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sayi1= int(input("Birinci sayıyı giriniz: "))
sayi2= int(input("İkinci sayıyı giriniz: "))

def toplama(sayi1,sayi2):
    sonuc= sayi1+sayi2
    print(sonuc)
    return sonuc

def cikarma(sayi1,sayi2):
    sonuc= sayi1-sayi2
    print(sonuc)
    return sonuc
def carpma(sayi1,sayi2):
    sonuc= sayi1*sayi2
    print(sonuc)
    return sonuc
def bolme(sayi1,sayi2):
    sonuc= sayi1/sayi2
    print(sonuc)
    return sonuc

islem= str(input("""İşleminizi seçiniz: )
-Toplama
-Çıkarma
-Çarpma
-Bölme

"""))
if islem== "toplama" or islem=="Toplama":
    toplama(sayi1,sayi2)
elif islem== "çıkarma" or islem=="Çıkarma":
    cikarma(sayi1,sayi2)
elif islem== "çarpma" or islem=="Çarpma":
    carpma(sayi1,sayi2)
elif islem== "bölme" or islem=="Bölme":
    bolme(sayi1,sayi2)
else:
    print("""Lütfen belirtilen işlemlerden birini seçiniz.
    -Toplama
    -Çıkarma
    -Çarpma
    -Bölme""")
# Out:
# Birinci sayıyı giriniz: 123
# İkinci sayıyı giriniz: 234
# İşleminizi seçiniz: )
# -Toplama
# -Çıkarma
# -Çarpma
# -Bölme
#
# çarpma
# 28782

# %%
print("""Bu ilk satır.
Bu ikinci satır.
Ve bu da üçüncü satır.""")
# Out:
# Bu ilk satır.
# Bu ikinci satır.
# Ve bu da üçüncü satır.

# %% [markdown]
# Evet burada basit bir hesap makinesini başarıyla oluşturdum. Fakat ben yeni eklemeler yapmak istiyorum bu yüzden de bu hesap makinesine bir hafıza vermek de istiyorum. İlk başta sadece bir sonuç listesi ve bu listeyi göstermesi için kodlar oluşturacağım.
# Sonrasında bu listeye ekleme ve çıkarma yapmak için kodlar ekleyeceğim.
# Bakalım.

# %%
hafıza= []

def toplama(sayi1,sayi2):
    sonuc= sayi1+sayi2
    print(sonuc)
    hafıza.append(sonuc)
    return sonuc

def cikarma(sayi1,sayi2):
    sonuc= sayi1-sayi2
    print(sonuc)
    hafıza.append(sonuc)
    return sonuc

def carpma(sayi1,sayi2):
    sonuc= sayi1*sayi2
    print(sonuc)
    hafıza.append(sonuc)
    return sonuc

def bolme(sayi1,sayi2):
    sonuc= sayi1/sayi2
    print(sonuc)
    hafıza.append(sonuc)
    return sonuc
devam = "E"
while devam == "E" or devam== "e":
  sayi1= int(input("Birinci sayıyı giriniz: "))
  sayi2= int(input("İkinci sayıyı giriniz: "))
  islem= str(input("""
İşleminizi seçiniz:
-Toplama
-Çıkarma
-Çarpma
-Bölme
-Hafızayı görüntüle

"""))
  if islem == "toplama" or islem == "Toplama":
      toplama(sayi1,sayi2)
      devam= str(input("""Devam etmek istiyor musunuz? (E/H)
      """))
      islem=""
      sayi1=""
      sayi2=""
  elif islem == "çıkarma" or islem == "Çıkarma":
      cikarma(sayi1,sayi2)
      devam= str(input("""Devam etmek istiyor musunuz? (E/H)
      """))
      islem=""
      sayi1=""
      sayi2=""
  elif islem == "çarpma" or islem == "Çarpma":
      carpma(sayi1,sayi2)
      devam= str(input("""Devam etmek istiyor musunuz? (E/H)
      """))
      islem=""
      sayi1=""
      sayi2=""
  elif islem == "bölme" or islem == "Bölme":
      bolme(sayi1,sayi2)
      devam= str(input("""Devam etmek istiyor musunuz? (E/H)
      """))
      islem=""
      sayi1=""
      sayi2=""
  elif islem == "hafızayı görüntüle" or islem == "Hafızayı görüntüle" or islem == "Hafızayı Görüntüle":
      print(hafıza)
      if hafıza == []:
          print("Hafıza boş.")
      devam= str(input("""Devam etmek istiyor musunuz? (E/H)
      """))
      islem=""
      sayi1=""
      sayi2=""
  else:

      devam=="E"
else:
  print("""
Programdan çıkılıyor.""")
# Out:
# Birinci sayıyı giriniz: 412
# İkinci sayıyı giriniz: 234
#
# İşleminizi seçiniz:
# -Toplama
# -Çıkarma
# -Çarpma
# -Bölme
# -Hafızayı görüntüle
#
# çarpma
# 96408
# Devam etmek istiyor musunuz? (E/H)
#       h
#
# Programdan çıkılıyor.

# %% [markdown]
# Karşılaştığım hata her zaman toplama işlemi yapmasıydı ve yapay zekaya sorduğum zaman hatanın nedeninin
# - if islem== "toplama" or "Toplama":
#
# şeklindeki kodumda if sonucun her zaman true olarak çıkması olduğunu söyledi.
# Çözüm ise:
# - if islem== "toplama" or islem== "Toplama":
#
# şeklinde yazmak.

# %% [markdown]
# Uzun uğraşlar sonucunda programdan çıkmayı da ekledim.
#
# Benim için zor olan değişkenleri sıfırlayıp döngünün sonrasında yeniden belirlemek oldu.
#
# Fakat çözümü de tamamen kendim buldum ki bundan memnunum.

# %% [markdown]
# 11 Ekim 2025
#
# 22.30
